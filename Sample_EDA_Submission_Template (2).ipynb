# %% [markdown]
# # **Project Name**    -

# %% [markdown]
# # Global terrorism analysis project

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual
#
# ##### **Name**            - Anamika dhondiyal
# ##### **Roll No.**        - 2471005

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# ## Project Summary
#
# This project analyzes the Global Terrorism Dataset (1970–2017), which contains over 180,000 terrorist incidents worldwide.
#
# The objective is to identify patterns, trends, and insights related to terrorist activities such as attack types, regions affected, casualties, and weapon usage.
#
# Using Python libraries like
#  Pandas, NumPy, Matplotlib, and Seaborn, we perform data cleaning, exploration, and visualization to understand terrorism trends globally.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# Provide your GitHub Link here.

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# # Problem Statement
#
# The goal of this project is to analyze global terrorism data and answer key questions:
#
#
# This analysis helps in understanding patterns and supporting decision-making for security and policy planning.

# %% [markdown]
# **Write Problem Statement Here.**
#
# 1.   List item-
#     How have terrorist attacks changed over time?
#     What are the most common attack and weapon types?
# 2.   List item
#     Which countries and regions are most affected?
#     How severe are the attacks in terms of casualties?

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 20 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Optional: improve graph style
sns.set(style="whitegrid")

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset
import pandas as pd
from google.colab import files
uploaded = files.upload()

# Read the CSV file
df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1', low_memory=False)

# Show first few rows
df.head()

# %% [markdown]
# ### Dataset First View

# %%
df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
print("Number of Rows:", df.shape[0])
print("Number of Columns:", df.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
df.info()

# %% [markdown]
# #### Duplicate Values

# %%
df.duplicated().sum()

# %% [markdown]
# #### Missing Values/Null Values

# %%
df.isnull().sum()

# %%
# Visualizing Missing Values

plt.figure(figsize=(12,6))
sns.heatmap(df.isnull(), cbar=False)
plt.title("Missing Values Heatmap")
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# ## Observations
#
# - Dataset contains large number of records (more than 180,000)
# - Multiple columns with different data types (numeric and categorical)
# - Some columns contain missing values
# - Dataset includes information about attacks, regions, weapons, and casualties
# - Duplicate values are minimal or removed

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Dataset Columns
df.columns

# %%
# Dataset Describe
df.describe(include='all')

# %% [markdown]
# ## Variables Description
#
# - iyear → Year of attack
# - country_txt → Country name
# - region_txt → Region
# - city → City where attack happened
# - attacktype1_txt → Type of attack (bombing, assassination, etc.)
# - weaptype1_txt → Weapon used
# - targtype1_txt → Target type
# - gname → Terrorist group name
# - nkill → Number of people killed
# - nwound → Number of people wounded

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check Unique Values for each variable.
df.nunique()

# %% [markdown]
# ## 3. ***Data Wrangling***

# %%
print(df.columns)

# %%
df.columns = df.columns.str.strip()

# %%
# Data Wrangling Code

# 1. Select only important columns
df = df[['iyear','country_txt','region_txt','city',
         'attacktype1_txt','weaptype1_txt','targtype1_txt',
         'gname','nkill','nwound',]]

# 2. Handle missing values
df.loc[:, 'nkill'] = df['nkill'].fillna(0)
df['nwound'] = df['nwound'].fillna(0)

df['country_txt'] = df['country_txt'].fillna("Unknown")
df['city'] = df['city'].fillna("Unknown")
df['attacktype1_txt'] = df['attacktype1_txt'].fillna("Unknown")
df['weaptype1_txt'] = df['weaptype1_txt'].fillna("Unknown")
df['targtype1_txt'] = df['targtype1_txt'].fillna("Unknown")
df['gname'] = df['gname'].fillna("Unknown")

# 3. Remove duplicate rows
df = df.drop_duplicates()

# 4. Create a new column for total casualties
df['casualties'] = df['nkill'] + df['nwound']

# 5. Final dataset preview
df.head()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# ## Data Wrangling Summary & Insights
#
# - Selected only relevant columns to simplify analysis
# - Handled missing values by replacing them with appropriate values (0 or "Unknown")
# - Removed duplicate rows to improve data quality
# - Created a new column 'casualties' by combining killed and wounded counts
#
# ### Insights:
# - Dataset contains many missing values which were handled
# - Data cleaning helps in making analysis more accurate
# - New column 'casualties' helps measure total impact of attacks

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Chart - 1: Year-wise Terrorist Attacks

plt.figure(figsize=(12,6))

year_data = df['iyear'].value_counts().sort_index()

plt.plot(year_data.index, year_data.values, marker='o')

plt.title("Year-wise Terrorist Attacks Trend", fontsize=14)
plt.xlabel("Year")
plt.ylabel("Number of Attacks")

plt.grid()
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A line chart is used because it clearly shows trends over time. Since the data contains yearly information, a line graph helps visualize how terrorist attacks have increased or decreased over the years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The graph shows that terrorist attacks have increased significantly after the year 2000. There is a noticeable rise in attacks in recent years, indicating growing global terrorism trends.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights can help governments and security agencies identify periods of increased terrorist activity and take preventive measures. It helps in better planning and resource allocation for national security.
#
#
#
# Some years show a decline in attacks, which may indicate successful counter-terrorism efforts or improved security measures during those periods.

# %% [markdown]
# #### Chart - 2

# %%
# Chart - 2: Top 10 Affected Countries

plt.figure(figsize=(12,6))

top_country = df['country_txt'].value_counts().head(10)

sns.barplot(x=top_country.values, y=top_country.index)

plt.title("Top 10 Countries with Most Terrorist Attacks", fontsize=14)
plt.xlabel("Number of Attacks")
plt.ylabel("Country")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used because it is best for comparing different categories. Here, it helps compare the number of terrorist attacks across different countries clearly.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that a few countries like Iraq, Afghanistan, and Pakistan have the highest number of terrorist attacks. This indicates that terrorism is concentrated in specific regions.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps governments and organizations focus security resources on high-risk countries. It supports better decision-making and risk management strategies.
#
#
# Countries with a very high number of attacks indicate unstable conditions, which can negatively affect economic growth, tourism, and public safety.

# %% [markdown]
# #### Chart - 3

# %%
# Chart - 3: Attack Types Distribution

plt.figure(figsize=(8,8))

attack_types = df['attacktype1_txt'].value_counts().head(6)

plt.pie(attack_types.values, labels=attack_types.index, autopct='%1.1f%%')

plt.title("Distribution of Attack Types")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is used because it shows the proportion of different categories clearly. It helps in understanding which type of attack is most common compared to others.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that bombing/explosion is the most common type of terrorist attack. Other attack types like armed assault and assassination are less frequent.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps security agencies focus on preventing the most common types of attacks, such as bombings. It helps in planning safety measures and improving surveillance systems.
#
#
#
# The dominance of certain attack types like bombings indicates a major security concern. It can negatively impact public safety, infrastructure, and economic stability.

# %% [markdown]
# #### Chart - 4

# %%
# Chart - 4: Weapon Types Used

plt.figure(figsize=(12,6))

sns.countplot(
    y='weaptype1_txt',
    data=df,
    order=df['weaptype1_txt'].value_counts().index[:10]
)

plt.title("Top 10 Weapon Types Used in Attacks", fontsize=14)
plt.xlabel("Number of Attacks")
plt.ylabel("Weapon Type")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is used because it helps compare the frequency of different categories. It clearly shows which weapons are used most often in terrorist attacks.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that explosives and firearms are the most commonly used weapons in terrorist attacks. Other weapon types are used less frequently.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps security agencies focus on controlling and monitoring the use of common weapons like explosives and firearms. It supports better security planning and prevention strategies.
#
#
#
# The frequent use of dangerous weapons like explosives indicates a high level of threat, which negatively affects public safety, infrastructure, and economic development.

# %% [markdown]
# #### Chart - 5

# %%
# Chart - 5: Casualties Distribution

plt.figure(figsize=(10,6))

sns.histplot(df['casualties'], bins=50)

plt.title("Distribution of Casualties in Terrorist Attacks", fontsize=14)
plt.xlabel("Number of Casualties")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used because it helps understand the distribution of numerical data. It shows how frequently different casualty values occur in the dataset.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that most attacks result in low casualties, while very few attacks result in extremely high casualties. This indicates that the data is highly skewed.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps authorities focus on preventing high-impact attacks. It supports better emergency planning and resource allocation for handling severe incidents.
#
#
#
#
# High casualty attacks have a severe negative impact on society, affecting public safety, economy, and infrastructure. These incidents create fear and instability.

# %% [markdown]
# #### Chart - 6

# %%
# Chart - 6: Region-wise Attacks

plt.figure(figsize=(12,6))

sns.countplot(
    y='region_txt',
    data=df,
    order=df['region_txt'].value_counts().index
)

plt.title("Region-wise Distribution of Terrorist Attacks", fontsize=14)
plt.xlabel("Number of Attacks")
plt.ylabel("Region")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A count plot is used to compare the number of attacks across different regions. It helps in identifying which regions are most affected by terrorism.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that regions like the Middle East & North Africa and South Asia have the highest number of terrorist attacks. Other regions have comparatively fewer incidents.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps governments and international organizations focus resources on high-risk regions. It supports better planning of security strategies and international cooperation.
#
#
# Regions with high terrorist activity face instability, which negatively impacts economic growth, tourism, and development. It creates long-term challenges for these regions.

# %% [markdown]
# #### Chart - 7

# %%
# Chart - 7: Target Types

plt.figure(figsize=(12,6))

top_targets = df['targtype1_txt'].value_counts().head(10)

sns.barplot(x=top_targets.values, y=top_targets.index)

plt.title("Top 10 Target Types in Terrorist Attacks", fontsize=14)
plt.xlabel("Number of Attacks")
plt.ylabel("Target Type")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used because it helps compare different categories clearly. It shows which types of targets are most frequently attacked.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that civilians and private property are the most common targets of terrorist attacks. This indicates that common people are highly affected.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps governments and organizations improve security for vulnerable groups like civilians. It helps in planning better safety measures and protection strategies.
#
#
#
#
# Frequent attacks on civilians create fear and instability in society. This negatively affects economic growth, public confidence, and overall development.

# %% [markdown]
# #### Chart - 8

# %%
# Chart - 8: Attack Types Distribution (Pie Chart)

import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

attack_counts = df['attacktype1_txt'].value_counts().head(6)

plt.pie(attack_counts.values, labels=attack_counts.index, autopct='%1.1f%%')

plt.title("Top 6 Attack Types Distribution")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pie chart is used to represent the proportion of different attack types. It helps in understanding which type of terrorist attack is most common compared to others.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows that bombing/explosion is the most common type of attack. Other attack types like armed assault and assassination are less frequent in comparison.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights help security agencies focus on preventing the most common types of attacks, such as bombings.
#
#  It supports better planning and implementation of safety measures.
# However, the dominance of certain attack types indicates a serious security concern, which negatively impacts public safety and infrastructure.

# %% [markdown]
# #### Chart - 9

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count number of attacks per year
year_counts = df['iyear'].value_counts().sort_index()

# Plot
plt.figure(figsize=(12,6))
sns.lineplot(x=year_counts.index, y=year_counts.values)

plt.title("Number of Terrorist Attacks per Year")
plt.xlabel("Year")
plt.ylabel("Number of Attacks")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# This chart is chosen to analyze the trend of terrorist attacks over time. A line plot is suitable for time-series data as it clearly shows increases or decreases across years.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The number of attacks changes significantly over different years.
# There is a noticeable increase in attacks during certain periods.
# Some years show peak activity, indicating periods of high instability.
# The trend helps identify whether attacks are rising or declining over time.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights help in creating a positive impact by identifying high-risk periods, which can assist governments and organizations in planning security strategies.
# Negative growth is observed in years with a sudden increase in attacks, as it indicates rising instability, economic disruption, and threats to public safety.

# %% [markdown]
# #### Chart - 10

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Top 10 countries with most attacks
top_countries = df['country_txt'].value_counts().head(10)

# Plot
plt.figure(figsize=(12,6))
sns.barplot(x=top_countries.values, y=top_countries.index)

plt.title("Top 10 Countries with Most Terrorist Attacks")
plt.xlabel("Number of Attacks")
plt.ylabel("Country")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is chosen to compare the number of terrorist attacks across different countries. It clearly highlights which countries are most affected and allows easy comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A few countries have significantly higher attack counts than others.
# Terrorist activities are concentrated in specific regions.
# Some countries consistently appear among the most affected.
# The difference between top countries and others is clearly visible.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights help governments and organizations focus security resources on high-risk countries, improving safety and planning.
# Negative growth is observed in countries with very high attack counts, as it indicates instability, reduced investment, and economic challenges.

# %% [markdown]
# #### Chart - 11

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Top regions with most attacks
region_counts = df['region_txt'].value_counts().head(10)

# Plot
plt.figure(figsize=(12,6))
sns.barplot(x=region_counts.values, y=region_counts.index)

plt.title("Top Regions with Most Terrorist Attacks")
plt.xlabel("Number of Attacks")
plt.ylabel("Region")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to compare terrorist activities across different regions. It clearly shows which regions are most affected and allows easy comparison.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Some regions have significantly higher attack counts than others.
# Terrorist activities are concentrated in specific geographical areas.
# A few regions dominate the overall number of attacks.
# This helps identify global hotspots of terrorism.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights help governments and organizations allocate resources and security measures to high-risk regions.
# Negative growth is seen in regions with high attack frequency, as it indicates instability, reduced economic growth, and safety concerns.

# %% [markdown]
# #### Chart - 12

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Top 10 attack types
attack_types = df['attacktype1_txt'].value_counts().head(10)

# Plot
plt.figure(figsize=(12,6))
sns.barplot(x=attack_types.values, y=attack_types.index)

plt.title("Top 10 Attack Types in Terrorist Activities")
plt.xlabel("Number of Attacks")
plt.ylabel("Attack Type")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A bar chart is used to compare different types of terrorist attacks. It clearly shows which attack types occur most frequently and helps in understanding patterns.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Certain attack types are used more frequently than others.
# A few categories dominate the overall attacks.
# The distribution shows preference or common methods used in attacks.
# This helps identify the most common forms of threats.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, these insights help security agencies focus on preventing the most common attack types and improve safety strategies.
#
#
#
# Negative growth is seen where a particular attack type is very frequent, as it indicates vulnerability in security systems and increased risk.

# %% [markdown]
# #### Chart - 13

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Histogram for casualties
plt.figure(figsize=(10,6))

sns.histplot(df['casualties'], bins=50, kde=True)

plt.title("Distribution of Total Casualties")
plt.xlabel("Number of Casualties")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A histogram is used to understand the distribution of casualties. It helps visualize how frequently different casualty levels occur and whether the data is skewed.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Most terrorist attacks result in low casualties.
# A small number of attacks cause very high casualties.
# The data is highly skewed (long tail distribution).
# Extreme events (outliers) exist with very high impact.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, this insight helps in focusing on preventing high-impact attacks and improving emergency response systems.
#
#
# Negative growth is seen in rare but high-casualty events, as they cause severe damage to society, economy, and public safety.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Chart - 14: Correlation Heatmap

import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8,6))

# Select only numeric columns
corr = df[['nkill','nwound','casualties']].corr()

sns.heatmap(corr, annot=True)

plt.title("Correlation Heatmap of Casualties")

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap is used to understand the relationship between numerical variables. It helps in identifying how strongly variables like number of kills, wounded, and total casualties are related to each other.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
#  The heatmap shows a strong positive correlation between number of kills, number of wounded, and total casualties. This indicates that as the number of people killed increases, the number of people wounded also tends to increase.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Chart - 15: Pair Plot

import seaborn as sns
import matplotlib.pyplot as plt

sample_df = df[['nkill','nwound','casualties']].sample(1000)

sns.pairplot(sample_df)

plt.suptitle("Pair Plot of Casualties Variables", y=1.02)

plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot is used to visualize relationships between multiple numerical variables at once. It helps in understanding distributions as well as pairwise relationships between variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows positive relationships between number of kills, wounded, and total casualties. It also shows that most data points are concentrated at lower values, indicating that most attacks result in fewer casualties.

# %% [markdown]
# ## **5. Solution to Business Objective**

# %% [markdown]
# #### What do you suggest the client to achieve Business Objective ?
# Explain Briefly.

# %% [markdown]
# Based on the analysis of the dataset, it is suggested that the client should focus on identifying high-risk regions, common attack types, and frequently targeted areas. By strengthening security measures in these hotspots and improving surveillance systems, the chances of terrorist attacks can be reduced. Additionally, better intelligence gathering, quick emergency response systems, and awareness programs can help in minimizing casualties and preventing future incidents.

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project, exploratory data analysis was performed on the global terrorism dataset to understand patterns, trends, and relationships between different variables. The analysis revealed that certain regions and attack types are more prone to terrorist activities, and most attacks result in relatively low casualties, although some have severe impacts. Visualizations such as bar charts, pie charts, heatmaps, and pair plots helped in gaining meaningful insights. Overall, the study highlights the importance of data-driven decision-making in improving security strategies and reducing the impact of terrorist attacks.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your EDA Capstone Project !!!***
